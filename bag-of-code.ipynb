# %%
import os
import pickle
import numpy as np
import pandas as pd

import npm_crawler as npm
import commonjs_package_tokenizer as t
import packages_term_indexer as pti_mod

from scipy import linalg
from github import Github
from os.path import isdir

# %%
# %%time

# spider npm's "most starred repositories" page for
# package name and a github url.
packages = list(npm.get_most_starred_packages(max_pages=40))

# providing a github login means we can exceed the public API request limit of 60 requests per hour.
# We need to look up approximately 400 packages.
gh_user = os.environ.get('GITHUB_API_USER')
gh_token = os.environ.get('GITHUB_API_TOKEN')
gh = Github(gh_user, gh_token)

# for each of those packages, perform a shallow git clone
for name, gh_url in packages:
    clone_url = 'git://github.com/{}.git'.format(gh_url)
    clone_dir = '.cache/packages/{}'.format(name)
    
    # use github API to determine if this repo is predominantly javascript.
    # we want to exclude coffeescript/typescript repos because their tokens
    # are significantly different.
    is_javascript = gh.is_repo_javascript(gh_url)
    
    if is_javascript and not isdir(clone_dir):
        # git clone the repo. assign output to an unused variable to supress noise
        _ = !git clone $clone_url $clone_dir --depth=1
# Out:
# CPU times: user 4.3 s, sys: 155 ms, total: 4.46 s
# Wall time: 4.9 s

# %%
# %%time
reload(t)
reload(pti_mod)

# build a document-term matrix for all the packages we downloaded
pti = pti_mod.PackagesTermIndexer()

i = 0
for name, gh_url in packages:
    if not isdir('.cache/packages/{}'.format(name)): continue
    if i >= 800: break
    i += 1

    pkg = pti_mod.Package(name, gh_url)
    for token in t.tokenize_package(name):
        pkg.register_term(token)
    pti.append(pkg)

print "{} packages indexed".format(i)
doer = pti.fit_trim()
# Out:
# 800 packages indexed
# CPU times: user 4min 33s, sys: 15.9 s, total: 4min 48s
# Wall time: 4min 56s

# %%
# %%time
wf_matrix = doer.word_frequency_matrix()
# Out:
# CPU times: user 324 ms, sys: 8.09 ms, total: 332 ms
# Wall time: 346 ms

# %%
# %%time
tfidf_matrix = doer.tfidf_matrix()
# Out:
# CPU times: user 214 ms, sys: 4.22 ms, total: 218 ms
# Wall time: 229 ms

# %%
# %%time
T,sigma,D_trans = doer.svd()
# Out:
# CPU times: user 255 ms, sys: 15 ms, total: 270 ms
# Wall time: 280 ms

# %%
print doer._global_term_count.keys()[0:10]
print doer.term_indices_[0:10]
# Out:
# ['=', '{', '*', 'var', '}', 'if', 'return', 'function', '//', 'the']
# ['=', '{', '*', 'var', '}', 'if', 'return', 'function', '//', 'the']

# %%
df = pd.DataFrame(wf_matrix, index=doer.term_indices_, columns=doer.package_names_)
df.head()
# Out:
#      gulp  async  request  lodash  browserify  grunt   pm2  commander  \
# =      51    159      407     390         321    162  1259         70
# {      40    226      226     202         246    126   991         36
# *       0     21        0      68           2     83   488        157
# var    36     92      109     153         129     76   663         19
# }      23     97      205      85         126     59   492         18
#
#      mongoose  mocha  ...    gsap  gulp-htmlhint  node-readability  updtr  \
# =        1195   1136  ...     558             16                52     53
# {         603    676  ...     272              6                29     55
# *        1584   1398  ...     481              0                12      0
# var       435    455  ...      93              7                25     32
# }         379    332  ...     180              2                17     29
#
#      cli-spinner  simple-git  rollup  grunt-html2js  grunt-html2js  updtr
# =             15         168     370             72             72     53
# {              6         170     365             70             70     55
# *              0         208       5             10             10      0
# var            9          59      31             50             50     32
# }              4          61     246             37             37     29
#
# [5 rows x 800 columns]

# %%
df = pd.DataFrame(tfidf_matrix, index=doer.term_indices_, columns=doer.package_names_)
df.head(50)
df[:'const']
# Out:
#                 gulp     async   request    lodash  browserify     grunt  \
# =           1.153424  1.481515  1.754774  1.742350    1.685673  1.486938
# {           1.140725  1.666421  1.666421  1.632096    1.692359  1.488024
# *           0.000000  1.568465  0.000000  2.148481    0.557461  2.248296
# var         1.116095  1.400977  1.452867  1.556867    1.504502  1.342623
# }           0.924379  1.333598  1.549683  1.295606    1.408996  1.190894
# if          0.880199  1.045745  1.450215  1.165928    1.531909  1.145390
# return      0.794723  1.378358  1.426475  1.548692    1.491350  0.992861
# function    0.725056  1.710362  1.486303  1.219156    1.495990  0.836094
# //          0.985301  1.164347  1.357436  1.066428    0.775682  1.445284
# the         0.310670  1.787870  1.442706  1.770955    0.721353  1.664430
# +           0.514919  1.245138  1.137488  1.340427    1.077323  1.287860
# });         0.950047  1.508202  0.000000  1.290859    1.615522  1.186911
# },          0.565589  2.081449  0.922436  1.858978    1.070541  1.185420
# */          0.000000  0.956815  0.000000  2.259447    0.000000  1.331564
# };          0.471250  1.178126  0.000000  1.270566    1.236544  1.120371
# /**         0.000000  0.000000  0.000000  2.535684    0.000000  0.000000
# @param      0.000000  0.000000  0.000000  1.969807    0.000000  0.000000
# ===         0.557460  1.123444  1.106155  0.746043    1.308182  0.932045
# new         0.668646  1.151881  1.337292  1.532556    0.808434  0.912844
# to          0.421913  1.265740  1.088073  1.740709    0.618092  1.064791
# ||          0.399078  0.798157  1.131871  0.738383    1.015148  0.632524
# &&          0.631379  1.155097  1.320983  1.175220    1.320983  0.702904
# -           0.000000  1.302169  1.122019  1.122019    0.000000  0.687963
# of          0.677020  1.213546  0.785996  1.552057    0.338510  1.354041
# ()          0.000000  1.705078  0.916042  0.000000    1.645110  0.000000
# for         0.440671  0.923604  0.961834  1.322013    0.556065  0.645571
# a           0.407729  1.223186  0.771745  0.922225    0.514496  0.771745
# function()  0.979773  1.090764  0.421965  1.337598    0.000000  1.759563
# :           0.422666  1.066689  1.367837  1.090013    0.885866  0.800017
# in          0.484853  1.223633  1.058269  1.486097    0.305908  0.790761
# ...              ...       ...       ...       ...         ...       ...
# an          0.000000  0.967821  0.305313  1.056211    0.000000  1.056211
# [];         0.000000  0.503825  0.000000  0.707208    0.755738  0.755738
# object      0.000000  1.481627  1.137703  1.311935    0.379234  0.601072
# null;       0.324227  1.162343  0.000000  0.000000    0.000000  0.324227
# callback    0.000000  0.561318  1.122635  0.561318    0.000000  0.000000
# &&          1.973431   0.543840  1.760883  1.447140    ...     1.579137
# -           1.809983   0.434056  2.369701  2.462152    ...     2.678095
# of          1.288829   0.677020  1.957049  1.736315    ...     1.661033
# ()          1.107552   0.000000  1.019814  0.000000    ...     0.000000
# for         1.479668   0.961834  1.742370  1.526913    ...     1.772468
# a           1.274458   0.597312  1.697816  1.697816    ...     1.350020
# function()  2.522204   0.668799  2.303690  2.725655    ...     2.070537
# :           2.443355   0.422666  1.171309  1.389217    ...     1.634510
# in          1.628022   0.305908  1.649555  1.486097    ...     2.109182
# ...              ...        ...       ...       ...    ...          ...
# an          0.915940   0.483910  1.273134  0.967821    ...     1.094537
# [];         1.223787   0.651185  1.106480  1.139543    ...     0.503825
# object      1.359541   0.000000  1.516937  0.601072    ...     0.980307
# null;       1.737066   0.324227  1.424110  1.121643    ...     0.513888
# callback    1.683953   0.889667  1.450985  2.340652    ...     0.000000
# {string}    2.773428   0.000000  0.693357  4.175650    ...     0.000000
# return;     1.126565   0.375522  1.299092  1.346231    ...     0.000000
# (var        1.472544   0.000000  1.541244  1.297222    ...     0.340715
# 0)          1.558418   0.324174  0.513803  1.162150    ...     1.325048
# 0           1.380907   0.000000  0.801592  0.345227    ...     0.892398
# +=          0.889456   0.000000  0.380970  0.915155    ...     0.674790
# this;       1.321838   0.889242  1.468494  2.078227    ...     0.592828
# break;      1.132970   0.694677  1.571262  1.516243    ...     0.694677
# true,       1.096496   0.000000  1.177166  0.000000    ...     0.456460
# file        1.811724   0.000000  0.849117  1.159225    ...     0.365695
# (typeof     0.874719   0.243997  0.844090  1.054536    ...     0.000000
# options     0.644783   0.214928  1.173382  0.972238    ...     0.000000
# 3,          0.000000   0.000000  0.000000  0.000000    ...     1.277751
# throw       1.077908   0.000000  1.219863  0.804366    ...     0.402183
# >           1.038806   0.508289  0.402809  0.590105    ...     1.180210
# /           1.337745   0.000000  1.182872  1.793887    ...     1.943931
# OR          0.000000   0.000000  0.000000  0.000000    ...     0.000000
# |           0.896856   0.000000  0.565853  1.793712    ...     1.313870
# on          1.010298   0.000000  1.314428  1.090294    ...     0.608260
# 1,          1.313273   0.000000  1.313273  1.209238    ...     1.677035
# 1           0.970038   0.375262  1.564814  0.375262    ...     1.428756
# =>          0.000000   1.338218  0.000000  0.000000    ...     0.000000
# name        1.524673   0.768377  1.362874  1.660123    ...     0.471128
# source      0.000000   0.000000  0.000000  0.831778    ...     0.000000
# const       1.407863   0.000000  0.000000  0.000000    ...     0.000000
#
#             gulp-htmlhint  node-readability     updtr  cli-spinner  \
# =                0.827055          1.158984  1.164441     0.809358
# {                0.597739          1.044770  1.236496     0.597739
# *                0.000000          1.301513  0.000000     0.000000
# var              0.642733          1.007042  1.080732     0.711704
# }                0.319546          0.840703  0.989283     0.468126
# if               0.422165          0.756723  0.880199     0.334558
# return           0.533408          0.763134  0.644923     0.000000
# =>            0.000000  3.532544       0.000000       0.000000  0.000000
# name          0.834483  1.668965       0.000000       0.000000  0.471128
# source        1.049587  2.268119       0.524793       0.524793  0.000000
# const         0.000000  3.641706       0.000000       0.000000  0.000000
#
# [95 rows x 800 columns]

# %%
# %%time
with open('.cache/pickle', 'w') as serialized_fd:
    pickle.dump(doer, serialized_fd)
# Out:
# CPU times: user 711 ms, sys: 45.2 ms, total: 757 ms
# Wall time: 765 ms

# %%
# %%time
reload(t)
other = pti_mod.Package('other-pkg', 'other/other')
for token in t.tokenize_package('../../../other-pkg'):
    other.register_term(token)
# Out:
# CPU times: user 278 ms, sys: 143 ms, total: 421 ms
# Wall time: 518 ms

# %%
# %%time

# folded_wfm = pti.fold_wfm(other)
# folded_tfidf = pti.fold_tfidf(other)
folded_svd = doer.fold_svd(other)
print folded_svd.shape
# Out:
# (1, 200)
# CPU times: user 3.66 ms, sys: 825 µs, total: 4.49 ms
# Wall time: 2.47 ms

# %%
T,_,_ = doer.svd()
T.shape
# Out:
# (200, 200)

# %%
def cosine_sim(a,b):
    ret = np.dot(a, b)/linalg.norm(a)/linalg.norm(b)
#     return linalg.norm(ret)
    return ret[0,0]

# %%
# %%time

other_doc_svd = doer.fold_svd(other)

cosines = []
for idx, pkg in enumerate(doer.package_names_):
    pkg_svd_vector = doer.svd()[2][:,idx]
    cos_svd = cosine_sim(other_doc_svd, pkg_svd_vector.T)
    cosines.append(cos_svd)
# Out:
# CPU times: user 57.5 ms, sys: 2.74 ms, total: 60.2 ms
# Wall time: 58.6 ms

# %%
# %%time

other_doc_wfm = doer.fold_wfm(other)
other_doc_tfidf = doer.fold_tfidf(other)
other_doc_svd = doer.fold_svd(other)
other_doc_svd_w = doer.fold_svd_wfm(other)

_,_,D_t = doer.svd()
_,_,Dw_t = doer.svd_wfm()
cosines = []
for idx, pkg in enumerate(doer.package_names_):
    pkg_svd_vector = D_t[:,idx]
    pkg_wfm_vector = doer.word_frequency_matrix()[:,idx]
    pkg_tfidf_vector = doer.tfidf_matrix()[:,idx]
    pkg_svd_w_vector = Dw_t[:, idx]

    cos_wfm = cosine_sim(other_doc_wfm, pkg_wfm_vector)
    cos_tfidf = cosine_sim(other_doc_tfidf, pkg_tfidf_vector)
    cos_svd = cosine_sim(other_doc_svd, pkg_svd_vector)
    cos_svd2 = cosine_sim(other_doc_svd_w, pkg_svd_w_vector)
    cosines.append([cos_wfm, cos_tfidf, cos_svd, cos_svd2])
# Out:
# CPU times: user 2min 32s, sys: 457 ms, total: 2min 32s
# Wall time: 2min 33s

# %%
df = pd.DataFrame(cosines, index=doer.package_github_urls_, columns=['wfm cosine', 'tfidf cosine', 'svd cosine (tfidf)', 'svd cosine (wfm)'])
df.head(20)
# Out:
#                           wfm cosine  tfidf cosine  svd cosine (tfidf)  \
# gulpjs/gulp                 0.891499      0.554683            0.010539
# caolan/async                0.812602      0.638968            0.031090
# request/request             0.907510      0.522324           -0.119423
# lodash/lodash               0.796841      0.515154           -0.078962
# substack/node-browserify    0.867803      0.616395           -0.015567
# gruntjs/grunt               0.845590      0.564191            0.030017
# Unitech/pm2                 0.816642      0.609625            0.023460
# tj/commander.js             0.461700      0.479682            0.052173
# Automattic/mongoose         0.621841      0.587146           -0.132320
# mochajs/mocha               0.622886      0.487286            0.017320
# nodejitsu/forever           0.843845      0.622322           -0.002542
# jashkenas/underscore        0.612397      0.473974           -0.089916
# bower/bower                 0.878245      0.664051           -0.053679
# moment/moment               0.668760      0.595636           -0.067685
# chalk/chalk                 0.711320      0.452122            0.024402
# kriskowal/q                 0.850732      0.586737            0.028782
# terinjokes/gulp-uglify      0.856144      0.485772            0.124669
# cheeriojs/cheerio           0.891601      0.544675           -0.172366
# npm/npm                     0.834737      0.638801            0.019783
# hapijs/hapi                 0.942515      0.813039            0.151185
#
#                           svd cosine (wfm)
# gulpjs/gulp                      -0.026279
# caolan/async                     -0.119499
# request/request                  -0.025122
# lodash/lodash                     0.110328
# substack/node-browserify         -0.093146
# gruntjs/grunt                     0.008254
# Unitech/pm2                      -0.079798
# tj/commander.js                   0.306596
# Automattic/mongoose              -0.002456
# mochajs/mocha                    -0.021776
# nodejitsu/forever                 0.090961
# jashkenas/underscore              0.148184
# bower/bower                       0.053848
# moment/moment                    -0.007488
# chalk/chalk                      -0.069590
# kriskowal/q                       0.052351
# terinjokes/gulp-uglify            0.006445
# cheeriojs/cheerio                 0.092161
# npm/npm                           0.067298
# hapijs/hapi                      -0.007051

# %%
df.sort_values(by='wfm cosine', ascending=False).head(10)
# Out:
#                       wfm cosine  tfidf cosine  svd cosine (tfidf)  \
# typicode/lowdb          0.956122      0.681455            0.193045
# tmpvar/jsdom            0.946214      0.785214            0.113753
# hapijs/hapi             0.942515      0.813039            0.151185
# tkellen/node-liftoff    0.938672      0.645644            0.188227
# assaf/zombie            0.937600      0.747826            0.049885
# flatiron/cradle         0.925962      0.599827            0.174824
# achingbrain/pm2-web     0.924032      0.684409            0.170383
# driftyco/ionic-cli      0.922947      0.624470           -0.090850
# jonkemp/gulp-useref     0.921974      0.542677           -0.104265
# hapijs/joi              0.916186      0.738691           -0.013973
#
#                       svd cosine (wfm)
# typicode/lowdb               -0.122726
# tmpvar/jsdom                 -0.032160
# hapijs/hapi                  -0.007051
# tkellen/node-liftoff         -0.052415
# assaf/zombie                  0.045956
# flatiron/cradle              -0.066150
# achingbrain/pm2-web          -0.108661
# driftyco/ionic-cli           -0.072793
# jonkemp/gulp-useref           0.024166
# hapijs/joi                    0.004320

# %%
df.sort_values(by='tfidf cosine', ascending=False).head(10)
# Out:
#                                       wfm cosine  tfidf cosine  \
# hapijs/hapi                             0.942515      0.813039
# hapijs/wreck                            0.915246      0.789695
# hapijs/lab                              0.915361      0.787593
# tmpvar/jsdom                            0.946214      0.785214
# assaf/zombie                            0.937600      0.747826
# kcbanner/connect-mongo                  0.858063      0.742989
# hapijs/joi                              0.916186      0.738691
# TryGhost/Ghost                          0.911955      0.722256
# mattdesl/budo                           0.891514      0.718931
# DaftMonk/generator-angular-fullstack    0.858493      0.715680
#
#                                       svd cosine (tfidf)  svd cosine (wfm)
# hapijs/hapi                                     0.151185         -0.007051
# hapijs/wreck                                    0.216174         -0.044098
# hapijs/lab                                      0.203169          0.042335
# tmpvar/jsdom                                    0.113753         -0.032160
# assaf/zombie                                    0.049885          0.045956
# kcbanner/connect-mongo                          0.223624         -0.133674
# hapijs/joi                                     -0.013973          0.004320
# TryGhost/Ghost                                  0.038463          0.065611
# mattdesl/budo                                   0.087661          0.118397
# DaftMonk/generator-angular-fullstack            0.085043          0.050577

# %%
df.sort_values(by='svd cosine (tfidf)', ascending=False).head(10)
# Out:
#                            wfm cosine  tfidf cosine  svd cosine (tfidf)  \
# kcbanner/connect-mongo       0.858063      0.742989            0.223624
# hapijs/wreck                 0.915246      0.789695            0.216174
# hapijs/lab                   0.915361      0.787593            0.203169
# maxogden/websocket-stream    0.828329      0.521541            0.199227
# typicode/lowdb               0.956122      0.681455            0.193045
# substack/hyperquest          0.841908      0.599551            0.189084
# tkellen/node-liftoff         0.938672      0.645644            0.188227
# bahmutov/next-update         0.845586      0.670346            0.183987
# vojtajina/grunt-bump         0.707589      0.406429            0.179167
# flatiron/cradle              0.925962      0.599827            0.174824
#
#                            svd cosine (wfm)
# kcbanner/connect-mongo            -0.133674
# hapijs/wreck                      -0.044098
# hapijs/lab                         0.042335
# maxogden/websocket-stream          0.028985
# typicode/lowdb                    -0.122726
# substack/hyperquest                0.009773
# tkellen/node-liftoff              -0.052415
# bahmutov/next-update               0.045248
# vojtajina/grunt-bump               0.103634
# flatiron/cradle                   -0.066150

# %%
df.sort_values(by='svd cosine (wfm)', ascending=False).head(10)
# Out:
#                            wfm cosine  tfidf cosine  svd cosine (tfidf)  \
# nodejitsu/node-http-proxy    0.369650      0.415926           -0.040986
# caolan/highland              0.826121      0.598436            0.031250
# tj/commander.js              0.461700      0.479682            0.052173
# request/request-promise      0.891105      0.524941           -0.063685
# rackt/redux                  0.456012      0.546762            0.028369
# chjj/marked                  0.871399      0.423206           -0.048322
# aacerox/node-rest-client     0.762054      0.448322           -0.015489
# flatiron/prompt              0.760433      0.418703           -0.134469
# Gozala/crypto                0.389367      0.271264           -0.069198
# visionmedia/supertest        0.519356      0.313592            0.054026
#
#                            svd cosine (wfm)
# nodejitsu/node-http-proxy          0.375926
# caolan/highland                    0.341196
# tj/commander.js                    0.306596
# request/request-promise            0.304220
# rackt/redux                        0.293482
# chjj/marked                        0.293413
# aacerox/node-rest-client           0.276248
# flatiron/prompt                    0.260714
# Gozala/crypto                      0.246596
# visionmedia/supertest              0.236798
